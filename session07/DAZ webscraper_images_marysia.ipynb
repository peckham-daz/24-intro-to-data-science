# %%
#import required libraries

# full imports go first
import os # os is a built-in Python library for interacting with the operating system
import requests # requests is a library for managing requests

# partial imports go below
from bs4 import BeautifulSoup # add to requirements.txt: beautifulsoup4
from PIL import Image # add to requirements.txt: pillow

# %%
### GETTING ALL IMAGES FROM A PAGE

# %%
URL = "https://en.wikipedia.org/wiki/Narwhal"
data = requests.get(URL)
html_text = data.text  # raw text

# %%
bs_html = BeautifulSoup(html_text, "html.parser")

# %%
# preview the html contents
print(bs_html.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Narwhal - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":[
# "",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"89ef18da-bf5f-408b-bcff-5017eeed70dd","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Narwhal","wgTitle":"Narwhal","wgCurRevisionId":1239588448,"wgRevisionId":1239588448,"wgArticleId":53484,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Latin-language sources (la)","CS1 French-language sources (fr)","Articles with short description","Short description is different from Wikidata","Wikipedia pages semi-protected against vandalism","Good articles","Use British English from May 2024","Use dmy dates from August 2024","Articles with 'species' microformats","Articles containing Old Norse-language text","Articles containing Inuktitut-language text","Taxonbars with 25–29 taxon IDs",
# "Articles with BNF identifiers","Articles with BNFdata identifiers","Articles with GND identifiers","Articles with J9U identifiers","Articles with LCCN identifiers","Articles with NDL identifiers","Articles containing video clips","IUCN Red List least concern species","Mammals described in 1758","Cetaceans of the Arctic Ocean","Mammals of Canada","Mammals of Greenland","Mammals of Russia","Monodontidae","Unicorns","Taxa named by Carl Linnaeus","Holarctic fauna","Fauna of Northern Canada"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Narwhal","wgRelevantArticleId":53484,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{
# "pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":90000,"wgULSCurrentAutonym":"English","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q159426","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready",
# "user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions",
# "wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession","wikibase.sidebar.tracking"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%7Cjquery.makeCollapsible.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
#   <meta content="MediaWiki 1.43.0-wmf.17" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="max-image-preview:standard" name="robots"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/1200px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="800" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/800px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="533" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/640px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg" property="og:image"/>
#   <meta content="640" property="og:image:width"/>
#   <meta content="427" property="og:image:height"/>
#   <meta content="width=1120" name="viewport"/>
#   <meta content="Narwhal - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/Narwhal" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="icon"/>
#   <link href="/w/rest.php/v1/search" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://en.wikipedia.org/wiki/Narwhal" rel="canonical"/>
#   <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.en" rel="license"/>
#   <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch">
#    <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   </link>
#  </head>
#  <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Narwhal rootpage-Narwhal skin-vector-2022 action-view">
#   <a class="mw-jump-link" href="#bodyContent">
#    Jump to content
#   </a>
#   <div class="vector-header-container">
#    <header class="vector-header mw-header">
#     <div class="vector-header-start">
#      <nav aria-label="Site" class="vector-main-menu-landmark">
#       <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
#        <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
#        <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label">
#         <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu">
#         </span>
#         <span class="vector-dropdown-label-text">
#          Main menu
#         </span>
#        </label>
#        <div class="vector-dropdown-content">
#         <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
#          <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
#           <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
#            <div class="vector-pinnable-header-label">
#             Main menu
#            </div>
#            <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">
#             move to sidebar
#            </button>
#            <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">
#             hide
#            </button>
#           </div>
#           <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
#            <div class="vector-menu-heading">
#             Navigation
#            </div>
#            <div class="vector-menu-content">
#             <ul class="vector-menu-content-list">
#              <li class="mw-list-item" id="n-mainpage-description">
#               <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#                <span>
#                 Main page
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-contents">
#               <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#                <span>
#                 Contents
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-currentevents">
#               <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#                <span>
#                 Current events
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-randompage">
#               <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#                <span>
#                 Random article
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-aboutsite">
#               <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#                <span>
#                 About Wikipedia
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-contactpage">
#               <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#                <span>
#                 Contact us
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-sitesupport">
#               <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#                <span>
#                 Donate
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
#            <div class="vector-menu-heading">
#             Contribute
#            </div>
#            <div class="vector-menu-content">
#             <ul class="vector-menu-content-list">
#              <li class="mw-list-item" id="n-help">
#               <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#                <span>
#                 Help
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-introduction">
#               <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#                <span>
#                 Learn to edit
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-portal">
#               <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#                <span>
#                 Community portal
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-recentchanges">
#               <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#                <span>
#                 Recent changes
#                </span>
#               </a>
#              </li>
#              <li class="mw-list-item" id="n-upload">
#               <a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia">
#                <span>
#                 Upload file
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#      <a class="mw-logo" href="/wiki/Main_Page">
#       <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
#       <span class="mw-logo-container skin-invert">
#        <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
#        <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
#       </span>
#      </a>
#     </div>
#     <div class="vector-header-end">
#      <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
#       <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" title="Search Wikipedia [f]">
#        <span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search">
#        </span>
#        <span>
#         Search
#        </span>
#       </a>
#       <div class="vector-typeahead-search-container">
#        <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
#         <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
#          <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
#           <div class="cdx-text-input cdx-text-input--has-start-icon">
#            <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#            <span class="cdx-text-input__icon cdx-text-input__start-icon">
#            </span>
#           </div>
#           <input name="title" type="hidden" value="Special:Search"/>
#          </div>
#          <button class="cdx-button cdx-search-input__end-button">
#           Search
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <nav aria-label="Personal tools" class="vector-user-links vector-user-links-wide">
#       <div class="vector-user-links-main">
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-preferences">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-userpage">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <nav aria-label="Appearance" class="vector-appearance-landmark">
#         <div class="vector-dropdown" id="vector-appearance-dropdown">
#          <input aria-haspopup="true" aria-label="Appearance" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-appearance-dropdown" id="vector-appearance-dropdown-checkbox" role="button" type="checkbox"/>
#          <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-appearance-dropdown-checkbox" id="vector-appearance-dropdown-label">
#           <span class="vector-icon mw-ui-icon-appearance mw-ui-icon-wikimedia-appearance">
#           </span>
#           <span class="vector-dropdown-label-text">
#            Appearance
#           </span>
#          </label>
#          <div class="vector-dropdown-content">
#           <div class="vector-unpinned-container" id="vector-appearance-unpinned-container">
#           </div>
#          </div>
#         </div>
#        </nav>
#        <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-notifications">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#          </ul>
#         </div>
#        </div>
#        <div class="vector-menu mw-portlet" id="p-vector-user-menu-overflow">
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-createaccount-2">
#            <a class="" data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=Narwhal" title="You are encouraged to create an account and log in; however, it is not mandatory">
#             <span>
#              Create account
#             </span>
#            </a>
#           </li>
#           <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-login-2">
#            <a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=Narwhal" title="You're encouraged to log in; however, it's not mandatory. [o]">
#             <span>
#              Log in
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Log in and more options">
#        <input aria-haspopup="true" aria-label="Personal tools" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
#        <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label">
#         <span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis">
#         </span>
#         <span class="vector-dropdown-label-text">
#          Personal tools
#         </span>
#        </label>
#        <div class="vector-dropdown-content">
#         <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount">
#             <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Narwhal" title="You are encouraged to create an account and log in; however, it is not mandatory">
#              <span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd">
#              </span>
#              <span>
#               Create account
#              </span>
#             </a>
#            </li>
#            <li class="user-links-collapsible-item mw-list-item" id="pt-login">
#             <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Narwhal" title="You're encouraged to log in; however, it's not mandatory. [o]">
#              <span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn">
#              </span>
#              <span>
#               Log in
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
#          <div class="vector-menu-heading">
#           Pages for logged out editors
#           <a aria-label="Learn more about editing" href="/wiki/Help:Introduction">
#            <span>
#             learn more
#            </span>
#           </a>
#          </div>
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="mw-list-item" id="pt-anoncontribs">
#             <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]">
#              <span>
#               Contributions
#              </span>
#             </a>
#            </li>
#            <li class="mw-list-item" id="pt-anontalk">
#             <a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]">
#              <span>
#               Talk
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#    </header>
#   </div>
#   <div class="mw-page-container">
#    <div class="mw-page-container-inner">
#     <div class="vector-sitenotice-container">
#      <div class="notheme" id="siteNotice">
#       <!-- CentralNotice -->
#      </div>
#     </div>
#     <div class="vector-column-start">
#      <div class="vector-main-menu-container">
#       <div id="mw-navigation">
#        <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel">
#         <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
#         </div>
#        </nav>
#       </div>
#      </div>
#      <div class="vector-sticky-pinned-container">
#       <nav aria-label="Contents" class="mw-table-of-contents-container vector-toc-landmark" data-event-name="ui.sidebar-toc" id="mw-panel-toc">
#        <div class="vector-pinned-container" id="vector-toc-pinned-container">
#         <div class="vector-toc vector-pinnable-element" id="vector-toc">
#          <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
#           <h2 class="vector-pinnable-header-label">
#            Contents
#           </h2>
#           <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">
#            move to sidebar
#           </button>
#           <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">
#            hide
#           </button>
#          </div>
#          <ul class="vector-toc-contents" id="mw-panel-toc-list">
#           <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
#            <a class="vector-toc-link" href="#">
#             <div class="vector-toc-text">
#              (Top)
#             </div>
#            </a>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Taxonomy">
#            <a class="vector-toc-link" href="#Taxonomy">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               1
#              </span>
#              <span>
#               Taxonomy
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Taxonomy-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Taxonomy subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Taxonomy-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Evolution">
#              <a class="vector-toc-link" href="#Evolution">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 1.1
#                </span>
#                <span>
#                 Evolution
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Evolution-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Description">
#            <a class="vector-toc-link" href="#Description">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               2
#              </span>
#              <span>
#               Description
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Description-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Description subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Description-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Tusk">
#              <a class="vector-toc-link" href="#Tusk">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 2.1
#                </span>
#                <span>
#                 Tusk
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Tusk-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Vestigial_teeth">
#              <a class="vector-toc-link" href="#Vestigial_teeth">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 2.2
#                </span>
#                <span>
#                 Vestigial teeth
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Vestigial_teeth-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Distribution">
#            <a class="vector-toc-link" href="#Distribution">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               3
#              </span>
#              <span>
#               Distribution
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Distribution-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Distribution subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Distribution-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Migration">
#              <a class="vector-toc-link" href="#Migration">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 3.1
#                </span>
#                <span>
#                 Migration
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Migration-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Behaviour_and_ecology">
#            <a class="vector-toc-link" href="#Behaviour_and_ecology">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               4
#              </span>
#              <span>
#               Behaviour and ecology
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Behaviour_and_ecology-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Behaviour and ecology subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Behaviour_and_ecology-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Diet">
#              <a class="vector-toc-link" href="#Diet">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.1
#                </span>
#                <span>
#                 Diet
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Diet-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Breeding">
#              <a class="vector-toc-link" href="#Breeding">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.2
#                </span>
#                <span>
#                 Breeding
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Breeding-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Communication">
#              <a class="vector-toc-link" href="#Communication">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.3
#                </span>
#                <span>
#                 Communication
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Communication-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Longevity_and_mortality_factors">
#              <a class="vector-toc-link" href="#Longevity_and_mortality_factors">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 4.4
#                </span>
#                <span>
#                 Longevity and mortality factors
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Longevity_and_mortality_factors-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Conservation">
#            <a class="vector-toc-link" href="#Conservation">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               5
#              </span>
#              <span>
#               Conservation
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Conservation-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Conservation subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Conservation-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Threats">
#              <a class="vector-toc-link" href="#Threats">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 5.1
#                </span>
#                <span>
#                 Threats
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Threats-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Relationship_with_humans">
#            <a class="vector-toc-link" href="#Relationship_with_humans">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               6
#              </span>
#              <span>
#               Relationship with humans
#              </span>
#             </div>
#            </a>
#            <button aria-controls="toc-Relationship_with_humans-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
#             <span class="vector-icon mw-ui-icon-wikimedia-expand">
#             </span>
#             <span>
#              Toggle Relationship with humans subsection
#             </span>
#            </button>
#            <ul class="vector-toc-list" id="toc-Relationship_with_humans-sublist">
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Inuit">
#              <a class="vector-toc-link" href="#Inuit">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 6.1
#                </span>
#                <span>
#                 Inuit
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Inuit-sublist">
#              </ul>
#             </li>
#             <li class="vector-toc-list-item vector-toc-level-2" id="toc-Tusk_trade">
#              <a class="vector-toc-link" href="#Tusk_trade">
#               <div class="vector-toc-text">
#                <span class="vector-toc-numb">
#                 6.2
#                </span>
#                <span>
#                 Tusk trade
#                </span>
#               </div>
#              </a>
#              <ul class="vector-toc-list" id="toc-Tusk_trade-sublist">
#              </ul>
#             </li>
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-References">
#            <a class="vector-toc-link" href="#References">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               7
#              </span>
#              <span>
#               References
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-References-sublist">
#            </ul>
#           </li>
#           <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Further_reading">
#            <a class="vector-toc-link" href="#Further_reading">
#             <div class="vector-toc-text">
#              <span class="vector-toc-numb">
#               8
#              </span>
#              <span>
#               Further reading
#              </span>
#             </div>
#            </a>
#            <ul class="vector-toc-list" id="toc-Further_reading-sublist">
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#     <div class="mw-content-container">
#      <main class="mw-body" id="content">
#       <header class="mw-body-header vector-page-titlebar">
#        <nav aria-label="Contents" class="vector-toc-landmark">
#         <div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
#          <input aria-haspopup="true" aria-label="Toggle the table of contents" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
#          <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label">
#           <span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet">
#           </span>
#           <span class="vector-dropdown-label-text">
#            Toggle the table of contents
#           </span>
#          </label>
#          <div class="vector-dropdown-content">
#           <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
#           </div>
#          </div>
#         </div>
#        </nav>
#        <h1 class="firstHeading mw-first-heading" id="firstHeading">
#         <span class="mw-page-title-main">
#          Narwhal
#         </span>
#        </h1>
#        <div class="vector-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
#         <input aria-haspopup="true" aria-label="Go to an article in another language. Available in 82 languages" class="vector-dropdown-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
#         <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-82" for="p-lang-btn-checkbox" id="p-lang-btn-label">
#          <span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive">
#          </span>
#          <span class="vector-dropdown-label-text">
#           82 languages
#          </span>
#         </label>
#         <div class="vector-dropdown-content">
#          <div class="vector-menu-content">
#           <ul class="vector-menu-content-list">
#            <li class="interlanguage-link interwiki-af mw-list-item">
#             <a class="interlanguage-link-target" href="https://af.wikipedia.org/wiki/Narwal" hreflang="af" lang="af" title="Narwal – Afrikaans">
#              <span>
#               Afrikaans
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ang mw-list-item">
#             <a class="interlanguage-link-target" href="https://ang.wikipedia.org/wiki/N%C4%93ohw%C3%A6l" hreflang="ang" lang="ang" title="Nēohwæl – Old English">
#              <span>
#               Ænglisc
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ar mw-list-item">
#             <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%83%D8%B1%D9%83%D8%AF%D9%86_%D8%A7%D9%84%D8%A8%D8%AD%D8%B1" hreflang="ar" lang="ar" title="كركدن البحر – Arabic">
#              <span>
#               العربية
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-an mw-list-item">
#             <a class="interlanguage-link-target" href="https://an.wikipedia.org/wiki/Monodon_monoceros" hreflang="an" lang="an" title="Monodon monoceros – Aragonese">
#              <span>
#               Aragonés
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-az mw-list-item">
#             <a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/Narval" hreflang="az" lang="az" title="Narval – Azerbaijani">
#              <span>
#               Azərbaycanca
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-zh-min-nan mw-list-item">
#             <a class="interlanguage-link-target" href="https://zh-min-nan.wikipedia.org/wiki/Chi%CC%8Dt-kak" hreflang="nan" lang="nan" title="Chi̍t-kak – Minnan">
#              <span>
#               閩南語 / Bân-lâm-gú
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-be mw-list-item">
#             <a class="interlanguage-link-target" href="https://be.wikipedia.org/wiki/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB" hreflang="be" lang="be" title="Нарвал – Belarusian">
#              <span>
#               Беларуская
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-be-x-old mw-list-item">
#             <a class="interlanguage-link-target" href="https://be-tarask.wikipedia.org/wiki/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB" hreflang="be-tarask" lang="be-tarask" title="Нарвал – Belarusian (Taraškievica orthography)">
#              <span>
#               Беларуская (тарашкевіца)
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-bg mw-list-item">
#             <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB" hreflang="bg" lang="bg" title="Нарвал – Bulgarian">
#              <span>
#               Български
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-br mw-list-item">
#             <a class="interlanguage-link-target" href="https://br.wikipedia.org/wiki/Narwal" hreflang="br" lang="br" title="Narwal – Breton">
#              <span>
#               Brezhoneg
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ca mw-list-item">
#             <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/Narval" hreflang="ca" lang="ca" title="Narval – Catalan">
#              <span>
#               Català
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-ceb mw-list-item">
#             <a class="interlanguage-link-target" href="https://ceb.wikipedia.org/wiki/Monodon_monoceros" hreflang="ceb" lang="ceb" title="Monodon monoceros – Cebuano">
#              <span>
#               Cebuano
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-cs badge-Q17437798 badge-goodarticle mw-list-item" title="good article badge">
#             <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Narval" hreflang="cs" lang="cs" title="Narval – Czech">
#              <span>
#               Čeština
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-cy mw-list-item">
#             <a class="interlanguage-link-target" href="https://cy.wikipedia.org/wiki/Morfil_Uncorn" hreflang="cy" lang="cy" title="Morfil Uncorn – Welsh">
#              <span>
#               Cymraeg
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-da mw-list-item">
#             <a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/Narhval" hreflang="da" lang="da" title="Narhval – Danish">
#              <span>
#               Dansk
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-de mw-list-item">
#             <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Narwal" hreflang="de" lang="de" title="Narwal – German">
#              <span>
#               Deutsch
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-nv mw-list-item">
#             <a class="interlanguage-link-target" href="https://nv.wikipedia.org/wiki/T%C3%A9%C3%A9h_h%C3%B3y%C3%A1anii_b%C3%ADch%C4%AF%CC%81%C4%AF%CC%81htsah%C3%AD" hreflang="nv" lang="nv" title="Tééh hóyáanii bíchį́į́htsahí – Navajo">
#              <span>
#               Diné bizaad
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-et mw-list-item">
#             <a class="interlanguage-link-target" href="https://et.wikipedia.org/wiki/Narval" hreflang="et" lang="et" title="Narval – Estonian">
#              <span>
#               Eesti
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-el mw-list-item">
#             <a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/%CE%9D%CE%B1%CF%81%CE%B2%CE%AC%CE%BB" hreflang="el" lang="el" title="Ναρβάλ – Greek">
#              <span>
#               Ελληνικά
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-es badge-Q17437798 badge-goodarticle mw-list-item" title="good article badge">
#             <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Monodon_monoceros" hreflang="es" lang="es" title="Monodon monoceros – Spanish">
#              <span>
#               Español
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-eo badge-Q17437796 badge-featuredarticle mw-list-item" title="featured article badge">
#             <a class="interlanguage-link-target" href="https://eo.wikipedia.org/wiki/Narvalo" hreflang="eo" lang="eo" title="Narvalo – Esperanto">
#              <span>
#               Esperanto
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-eu mw-list-item">
#             <a class="interlanguage-link-target" href="https://eu.wikipedia.org/wiki/Narbal" hreflang="eu" lang="eu" title="Narbal – Basque">
#              <span>
#               Euskara
#              </span>
#             </a>
#            </li>
#            <li class="interlanguage-link interwiki-fa mw-list-item">
# ...
#     dataWrapper <mw.lua:672>                                         220 ms       12.2%
#     ?                                                                180 ms       10.0%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::getEntity      180 ms       10.0%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::expandTemplate      160 ms        8.9%
#     recursiveClone <mwInit.lua:45>                                   120 ms        6.7%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::find      120 ms        6.7%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::gsub       60 ms        3.3%
#     <mw.lua:694>                                                      60 ms        3.3%
#     is_generic <Module:Citation/CS1:1496>                             40 ms        2.2%
#     [others]                                                         380 ms       21.1%
# Number of Wikibase entities loaded: 30/400
# -->
#           <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00% 3065.881      1 -total
#  28.42%  871.393      1 Template:Reflist
#  26.54%  813.540      1 Template:Speciesbox
#  26.15%  801.687      1 Template:Taxobox/core
#  13.74%  421.169     64 Template:Cite_journal
#  10.89%  333.980      1 Template:Taxonbar
#   8.24%  252.661     76 Template:Period_start
#   6.68%  204.822      2 Template:Navbox_with_collapsible_groups
#   6.55%  200.689      9 Template:Clade
#   6.28%  192.538     22 Template:Cite_book
# -->
#           <!-- Saved in parser cache with key enwiki:pcache:idhash:53484-0!canonical and timestamp 20240811012506 and revision id 1239588448. Rendering was triggered because: page-view
#  -->
#          </meta>
#         </div>
#         <!--esi <esi:include src="/esitest-fa8a495983347898/content" /> -->
#         <noscript>
#          <img alt="" height="1" src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" width="1"/>
#         </noscript>
#         <div class="printfooter" data-nosnippet="">
#          Retrieved from "
#          <a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Narwhal&amp;oldid=1239588448">
#           https://en.wikipedia.org/w/index.php?title=Narwhal&amp;oldid=1239588448
#          </a>
#          "
#         </div>
#        </div>
#        <div class="catlinks" data-mw="interface" id="catlinks">
#         <div class="mw-normal-catlinks" id="mw-normal-catlinks">
#          <a href="/wiki/Help:Category" title="Help:Category">
#           Categories
#          </a>
#          :
#          <ul>
#           <li>
#            <a href="/wiki/Category:IUCN_Red_List_least_concern_species" title="Category:IUCN Red List least concern species">
#             IUCN Red List least concern species
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Mammals_described_in_1758" title="Category:Mammals described in 1758">
#             Mammals described in 1758
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Cetaceans_of_the_Arctic_Ocean" title="Category:Cetaceans of the Arctic Ocean">
#             Cetaceans of the Arctic Ocean
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Mammals_of_Canada" title="Category:Mammals of Canada">
#             Mammals of Canada
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Mammals_of_Greenland" title="Category:Mammals of Greenland">
#             Mammals of Greenland
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Mammals_of_Russia" title="Category:Mammals of Russia">
#             Mammals of Russia
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Monodontidae" title="Category:Monodontidae">
#             Monodontidae
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Unicorns" title="Category:Unicorns">
#             Unicorns
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Taxa_named_by_Carl_Linnaeus" title="Category:Taxa named by Carl Linnaeus">
#             Taxa named by Carl Linnaeus
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Holarctic_fauna" title="Category:Holarctic fauna">
#             Holarctic fauna
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Fauna_of_Northern_Canada" title="Category:Fauna of Northern Canada">
#             Fauna of Northern Canada
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">
#          Hidden categories:
#          <ul>
#           <li>
#            <a href="/wiki/Category:CS1_Latin-language_sources_(la)" title="Category:CS1 Latin-language sources (la)">
#             CS1 Latin-language sources (la)
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:CS1_French-language_sources_(fr)" title="Category:CS1 French-language sources (fr)">
#             CS1 French-language sources (fr)
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">
#             Articles with short description
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">
#             Short description is different from Wikidata
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Wikipedia_pages_semi-protected_against_vandalism" title="Category:Wikipedia pages semi-protected against vandalism">
#             Wikipedia pages semi-protected against vandalism
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Good_articles" title="Category:Good articles">
#             Good articles
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Use_British_English_from_May_2024" title="Category:Use British English from May 2024">
#             Use British English from May 2024
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Use_dmy_dates_from_August_2024" title="Category:Use dmy dates from August 2024">
#             Use dmy dates from August 2024
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_%27species%27_microformats" title="Category:Articles with 'species' microformats">
#             Articles with 'species' microformats
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_containing_Old_Norse-language_text" title="Category:Articles containing Old Norse-language text">
#             Articles containing Old Norse-language text
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_containing_Inuktitut-language_text" title="Category:Articles containing Inuktitut-language text">
#             Articles containing Inuktitut-language text
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Taxonbars_with_25%E2%80%9329_taxon_IDs" title="Category:Taxonbars with 25–29 taxon IDs">
#             Taxonbars with 25–29 taxon IDs
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_BNF_identifiers" title="Category:Articles with BNF identifiers">
#             Articles with BNF identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_BNFdata_identifiers" title="Category:Articles with BNFdata identifiers">
#             Articles with BNFdata identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_GND_identifiers" title="Category:Articles with GND identifiers">
#             Articles with GND identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_J9U_identifiers" title="Category:Articles with J9U identifiers">
#             Articles with J9U identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_LCCN_identifiers" title="Category:Articles with LCCN identifiers">
#             Articles with LCCN identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_with_NDL_identifiers" title="Category:Articles with NDL identifiers">
#             Articles with NDL identifiers
#            </a>
#           </li>
#           <li>
#            <a href="/wiki/Category:Articles_containing_video_clips" title="Category:Articles containing video clips">
#             Articles containing video clips
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </main>
#     </div>
#     <div class="mw-footer-container">
#      <footer class="mw-footer" id="footer">
#       <ul id="footer-info">
#        <li id="footer-info-lastmod">
#         This page was last edited on 10 August 2024, at 07:25
#         <span class="anonymous-show">
#          (UTC)
#         </span>
#         .
#        </li>
#        <li id="footer-info-copyright">
#         Text is available under the
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license">
#          Creative Commons Attribution-ShareAlike License 4.0
#         </a>
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license" style="display:none;">
#         </a>
#         ;
# additional terms may apply. By using this site, you agree to the
#         <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use">
#          Terms of Use
#         </a>
#         and
#         <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">
#          Privacy Policy
#         </a>
#         . Wikipedia® is a registered trademark of the
#         <a href="//wikimediafoundation.org/">
#          Wikimedia Foundation, Inc.
#         </a>
#         , a non-profit organization.
#        </li>
#       </ul>
#       <ul id="footer-places">
#        <li id="footer-places-privacy">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">
#          Privacy policy
#         </a>
#        </li>
#        <li id="footer-places-about">
#         <a href="/wiki/Wikipedia:About">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="footer-places-disclaimers">
#         <a href="/wiki/Wikipedia:General_disclaimer">
#          Disclaimers
#         </a>
#        </li>
#        <li id="footer-places-contact">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#          Contact Wikipedia
#         </a>
#        </li>
#        <li id="footer-places-wm-codeofconduct">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">
#          Code of Conduct
#         </a>
#        </li>
#        <li id="footer-places-developers">
#         <a href="https://developer.wikimedia.org">
#          Developers
#         </a>
#        </li>
#        <li id="footer-places-statslink">
#         <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#          Statistics
#         </a>
#        </li>
#        <li id="footer-places-cookiestatement">
#         <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">
#          Cookie statement
#         </a>
#        </li>
#        <li id="footer-places-mobileview">
#         <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Narwhal&amp;mobileaction=toggle_view_mobile">
#          Mobile view
#         </a>
#        </li>
#       </ul>
#       <ul class="noprint" id="footer-icons">
#        <li id="footer-copyrightico">
#         <a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://wikimediafoundation.org/" style="padding-left: 8px; padding-right: 8px;" target="https://wikimediafoundation.org/">
#          <img alt="Wikimedia Foundation" height="29" src="/static/images/footer/wikimedia-button.svg" width="84"/>
#         </a>
#        </li>
#        <li id="footer-poweredbyico">
#         <a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://www.mediawiki.org" style="padding-left: 8px; padding-right: 8px;" target="https://www.mediawiki.org">
#          <img alt="Powered by MediaWiki" height="29" src="/static/images/footer/poweredby_mediawiki.svg" width="84"/>
#         </a>
#        </li>
#       </ul>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <div class="vector-settings" id="p-dock-bottom">
#    <ul>
#     <li>
#     </li>
#    </ul>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-698f8ff66d-l7pgj","wgBackendResponseTime":140,"wgPageParseReport":{"limitreport":{"cputime":"2.740","walltime":"3.463","ppvisitednodes":{"value":40918,"limit":1000000},"postexpandincludesize":{"value":1007024,"limit":2097152},"templateargumentsize":{"value":113905,"limit":2097152},"expansiondepth":{"value":28,"limit":100},"expensivefunctioncount":{"value":45,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":517088,"limit":5000000},"entityaccesscount":{"value":30,"limit":400},"timingprofile":["100.00% 3065.881      1 -total"," 28.42%  871.393      1 Template:Reflist"," 26.54%  813.540      1 Template:Speciesbox"," 26.15%  801.687      1 Template:Taxobox/core"," 13.74%  421.169     64 Template:Cite_journal"," 10.89%  333.980      1 Template:Taxonbar","  8.24%  252.661     76 Template:Period_start","  6.68%  204.822      2 Template:Navbox_with_collapsible_groups","  6.55%  200.689      9 Template:Clade","  6.28%  192.538     22 Template:Cite_book"]},"scribunto":{"limitreport-timeusage":{"value":"1.764","limit":"10.000"},"limitreport-memusage":{"value":22265625,"limit":52428800},"limitreport-profile":[["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::callParserFunction","280","15.6"],["dataWrapper \u003Cmw.lua:672\u003E","220","12.2"],["?","180","10.0"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::getEntity","180","10.0"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::expandTemplate","160","8.9"],["recursiveClone \u003CmwInit.lua:45\u003E","120","6.7"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::find","120","6.7"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::gsub","60","3.3"],["\u003Cmw.lua:694\u003E","60","3.3"],["is_generic \u003CModule:Citation/CS1:1496\u003E","40","2.2"],["[others]","380","21.1"]]},"cachereport":{"origin":"mw-web.eqiad.canary-cd87888c9-jkgxw","timestamp":"20240811012506","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Narwhal","url":"https:\/\/en.wikipedia.org\/wiki\/Narwhal","sameAs":"http:\/\/www.wikidata.org\/entity\/Q159426","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q159426","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2002-05-26T02:20:05Z","dateModified":"2024-08-10T07:25:58Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/b\/bc\/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg","headline":"medium-sized toothed whale that lives year-round in the Arctic"}
#   </script>
#  </body>
# </html>

# %%
image_tags = bs_html.find_all('img')

# %%
accepted_image_types = ['jpg', 'jpeg', 'png', 'bmp', 'webp', 'svg']

# %%
present_file_types = set(str(img_tag.get('src').split('.')[-1]) for img_tag in image_tags)

# %%
# what image types can we find on this page? Please note there may be some obsolete data in here
present_file_types
# Out:
# {'jpg', 'org/wiki/Special:CentralAutoLogin/start?type=1x1', 'png', 'svg'}

# %%
image_tags
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>,
#  <img alt="This is a good article. Click here for more information." class="mw-file-element" data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/>,
#  <img alt="Page semi-protected" class="mw-file-element" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>,
#  <img class="mw-file-element" data-file-height="1000" data-file-width="1500" decoding="async" height="147" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/220px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/330px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/440px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg 2x" width="220"/>,
#  <img alt="Diagram showing a narwhal and scuba diver from the side: the body of the whale is about three times longer than a human." class="mw-file-element" data-file-height="199" data-file-width="743" decoding="async" height="59" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Narwhal_size.svg/220px-Narwhal_size.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Narwhal_size.svg/330px-Narwhal_size.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Narwhal_size.svg/440px-Narwhal_size.svg.png 2x" width="220"/>,
#  <img alt="" class="mw-file-element" data-file-height="137" data-file-width="512" decoding="async" height="59" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Status_iucn3.1_LC.svg/220px-Status_iucn3.1_LC.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Status_iucn3.1_LC.svg/330px-Status_iucn3.1_LC.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Status_iucn3.1_LC.svg/440px-Status_iucn3.1_LC.svg.png 2x" width="220"/>,
#  <img alt="Edit this classification" class="mw-file-element" data-file-height="20" data-file-width="20" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/15px-OOjs_UI_icon_edit-ltr.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/23px-OOjs_UI_icon_edit-ltr.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/30px-OOjs_UI_icon_edit-ltr.svg.png 2x" width="15"/>,
#  <img class="mw-file-element" data-file-height="567" data-file-width="567" decoding="async" height="150" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Monodon_monoceros_distribution_map.svg/150px-Monodon_monoceros_distribution_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Monodon_monoceros_distribution_map.svg/225px-Monodon_monoceros_distribution_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/65/Monodon_monoceros_distribution_map.svg/300px-Monodon_monoceros_distribution_map.svg.png 2x" width="150"/>,
#  <img alt="Two narwhals at the water surface. They have irregular markings over a white background, extremely small pectoral fins and a large, broad tail." class="mw-file-element" data-file-height="2088" data-file-width="3944" decoding="async" height="106" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/62/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif/lossy-page1-200px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/62/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif/lossy-page1-300px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/62/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif/lossy-page1-400px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif.jpg 2x" width="200"/>,
#  <img alt="" class="mw-file-element" data-file-height="393" data-file-width="1665" decoding="async" height="47" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Monodon_monoceros_NOAA.jpg/200px-Monodon_monoceros_NOAA.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Monodon_monoceros_NOAA.jpg/300px-Monodon_monoceros_NOAA.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Monodon_monoceros_NOAA.jpg/400px-Monodon_monoceros_NOAA.jpg 2x" width="200"/>,
#  <img alt="The tusk of a male narwhal on display. The white tusk is long and shaped like a spiral." class="mw-file-element" data-file-height="2832" data-file-width="4256" decoding="async" height="146" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg/220px-Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg/330px-Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg/440px-Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg 2x" width="220"/>,
#  <img alt="Six narwhals near the water surface in the open ocean." class="mw-file-element" data-file-height="1080" data-file-width="1582" decoding="async" height="150" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/220px-%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/330px-%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/440px-%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg 2x" width="220"/>,
#  <img alt="Photo depicting narwhal tail flukes, which are broad, flat, and horizontal in shape." class="mw-file-element" data-file-height="680" data-file-width="1200" decoding="async" height="125" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Narwhal_tail_above_surface.jpg/220px-Narwhal_tail_above_surface.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Narwhal_tail_above_surface.jpg/330px-Narwhal_tail_above_surface.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/be/Narwhal_tail_above_surface.jpg/440px-Narwhal_tail_above_surface.jpg 2x" width="220"/>,
#  <img alt="Polar bear feeding/scavenging on a beached narwhal carcass." class="mw-file-element" data-file-height="578" data-file-width="1170" decoding="async" height="109" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png/220px-A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png/330px-A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fb/A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png/440px-A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png 2x" width="220"/>,
#  <img alt="Data showing the number of caught belugas and narwhals from 1954 to 2014. Belugas were reported from the US, Russia, Canada and Greenland, while narwhals were recorded from Canada and Russia." class="mw-file-element" data-file-height="677" data-file-width="583" decoding="async" height="360" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/76/Belugas%2BNarwhals.png/310px-Belugas%2BNarwhals.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/76/Belugas%2BNarwhals.png/465px-Belugas%2BNarwhals.png 1.5x, //upload.wikimedia.org/wikipedia/commons/7/76/Belugas%2BNarwhals.png 2x" width="310"/>,
#  <img alt="An Inuit man holding the head of a dead narwhal in the Arctic." class="mw-file-element" data-file-height="2030" data-file-width="1658" decoding="async" height="269" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg/220px-Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg/330px-Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg/440px-Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg 2x" width="220"/>,
#  <img alt="A goblet composed of narwhal tusk from Milan, Italy. The goblet is covered with jewels, has snake-shaped handles and a depiction of a woman at the top." class="mw-file-element" data-file-height="3338" data-file-width="2225" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Narwhal_Goblet_%2830061080057%29.jpg/220px-Narwhal_Goblet_%2830061080057%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Narwhal_Goblet_%2830061080057%29.jpg/330px-Narwhal_Goblet_%2830061080057%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Narwhal_Goblet_%2830061080057%29.jpg/440px-Narwhal_Goblet_%2830061080057%29.jpg 2x" width="220"/>,
#  <img alt="" class="mw-file-element" data-file-height="239" data-file-width="300" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/76/Sperm_whale_fluke.jpg/21px-Sperm_whale_fluke.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/76/Sperm_whale_fluke.jpg/32px-Sperm_whale_fluke.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/76/Sperm_whale_fluke.jpg/42px-Sperm_whale_fluke.jpg 2x" width="21"/>,
#  <img alt="icon" class="mw-file-element" data-file-height="1482" data-file-width="1707" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/18/Okapi2.jpg/21px-Okapi2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/18/Okapi2.jpg/32px-Okapi2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/18/Okapi2.jpg/42px-Okapi2.jpg 2x" width="21"/>,
#  <img alt="" class="mw-file-element" data-file-height="1039" data-file-width="1315" decoding="async" height="17" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Yellow.tang.arp.jpg/21px-Yellow.tang.arp.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Yellow.tang.arp.jpg/32px-Yellow.tang.arp.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Yellow.tang.arp.jpg/42px-Yellow.tang.arp.jpg 2x" width="21"/>,
#  <img alt="Edit this at Wikidata" class="mw-file-element" data-file-height="20" data-file-width="20" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" width="10"/>,
#  <img alt="" height="1" src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" width="1"/>,
#  <img alt="Wikimedia Foundation" height="29" src="/static/images/footer/wikimedia-button.svg" width="84"/>,
#  <img alt="Powered by MediaWiki" height="29" src="/static/images/footer/poweredby_mediawiki.svg" width="84"/>]

# %%
# how many tags?
len(image_tags)
# Out:
# 26

# %%
# extract the image URLs from the tags
# create an empty list
img_urls = []

for img_tag in image_tags:

    # if the tag has the 'src' property
    if img_tag.get('src'):

        # extract it
        img_src = img_tag.get('src')
        
        # get the image type (it's the last bit f text sfter the '.')
        img_type = img_src.split('.')[-1]
        
        # skip further steps in the loop for the current image if not in the accepted types
        if img_type.lower() in accepted_image_types and img_src.startswith('//upload'):
            img_urls.append(f'https:{img_src}')

# %%
image_tags[5].get('src')
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/220px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg'

# %%
# how many URLs did we get?
len(img_urls)
# Out:
# 20

# %%
# if you preview, quite a lot of them are duplicated
img_urls
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/220px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Narwhal_size.svg/220px-Narwhal_size.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Status_iucn3.1_LC.svg/220px-Status_iucn3.1_LC.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/15px-OOjs_UI_icon_edit-ltr.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/Monodon_monoceros_distribution_map.svg/150px-Monodon_monoceros_distribution_map.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif/lossy-page1-200px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D1%8B_%D0%B2_%D1%8E%D0%B6%D0%BD%D0%BE%D0%B9_%D1%87%D0%B0%D1%81%D1%82%D0%B8_%D0%B0%D1%80%D1%85%D0%B8%D0%BF%D0%B5%D0%BB%D0%B0%D0%B3%D0%B0_%D0%97%D0%B5%D0%BC%D0%BB%D1%8F_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B0-%D0%98%D0%BE%D1%81%D0%B8%D1%84%D0%B0.tif.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Monodon_monoceros_NOAA.jpg/200px-Monodon_monoceros_NOAA.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg/220px-Narwhal_tusk%2C_1701-1930_Wellcome_L0059030.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/220px-%D0%9E%D1%81%D0%BE%D0%B1%D0%B8_%D0%BD%D0%B0%D1%80%D0%B2%D0%B0%D0%BB%D0%B0_%D0%B2_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Narwhal_tail_above_surface.jpg/220px-Narwhal_tail_above_surface.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png/220px-A_polar_bear_%28Ursus_maritimus%29_scavenging_a_narwhal_whale_%28Monodon_monoceros%29_carcass_-_journal.pone.0060797.g001-A.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Belugas%2BNarwhals.png/310px-Belugas%2BNarwhals.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg/220px-Children_of_the_Arctic_%281903%29_%2814766096922%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Narwhal_Goblet_%2830061080057%29.jpg/220px-Narwhal_Goblet_%2830061080057%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Sperm_whale_fluke.jpg/21px-Sperm_whale_fluke.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Okapi2.jpg/21px-Okapi2.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Yellow.tang.arp.jpg/21px-Yellow.tang.arp.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png']

# %%
# how many unique?
unique_urls = set(img_urls)
len(unique_urls)
# Out:
# 20

# %%
# name of the folder where we want to sve the images. CAPITALS suggest it's a constant
IMAGES_DIRECTORY = "scraped_images"

current_dirs = os.listdir() # this function lists all the contents of the current folder (where the notebook is)
current_dirs
# Out:
# ["'Out There' Quick Mockup for Reference Trimmed.mp4",
#  '(CCI Re-created) PresentationTemplate PComp Modular.pptx',
#  '+44 invoice 07.06.24.docx.pdf',
#  '+44 invoice template.docx.pdf',
#  '.ipynb_checkpoints',
#  '028. 17 - Shada 19.00.mov',
#  '11052_Polyverse-Wider-V2.0.0+Win',
#  '11052_Polyverse-Wider-V2.0.0+Win.zip',
#  '11504_Native-Access_2',
#  '11504_Native-Access_2.zip',
#  '118978__esperri__windchimes-1.wav',
#  '1442_argotlunar-2.06.rar',
#  '1594_VacuumProFreshAIRPack1-1.1.0_Setup',
#  '1594_VacuumProFreshAIRPack1-1.1.0_Setup.zip',
#  '16.07.24 liv vox stems-20240716T151828Z-001',
#  '16.07.24 liv vox stems-20240716T151828Z-001.zip',
#  '1904-66_ZPN.fits.gz',
#  '2021-22 Consent to Share Information Form v1.pdf',
#  '20240626-lgwscq-gibbons-macgregor-bms74e-23e.pdf',
#  '2024_Peckham_DAZ_Web_Dev_session01.pdf',
#  '2024_Peckham_DAZ_Web_Dev_session02.pdf.pdf',
#  '3022_Filterjam-1.1.0_PC',
#  '3022_Filterjam-1.1.0_PC.zip',
#  '37106-413256452_medium.mp4',
#  '3847_iZotope_Ozone_Elements_v8_00',
#  '3847_iZotope_Ozone_Elements_v8_00.zip',
#  '3902465-5743287-proof-1.pdf',
#  '3902465-5743287-proof.pdf',
#  '3985_WAProd_ComBear_PC',
#  '3985_WAProd_ComBear_PC.zip',
#  '4250_DLYM_WIN',
#  '4250_DLYM_WIN.zip',
#  '45813__themfish__draw-card.wav',
#  '45813__themfish__draw-card.wav.asd',
#  '4894553.jpg',
#  '4961263_Fader_Knob__Slider_Cap_for_Roland_Juno-6__60__Jupiter_8__RS-09__CMU-810__EP-09',
#  '4961263_Fader_Knob__Slider_Cap_for_Roland_Juno-6__60__Jupiter_8__RS-09__CMU-810__EP-09.zip',
#  '525_WOLLO+BEAT+2.rar',
#  '567250__iwanplays__dropping-rocks.wav',
#  '57610206-antique-medical-scientific-illustration-bird-head-anatomy.jpg',
#  '6100_WIN_RoughRider_300',
#  '6100_WIN_RoughRider_300.zip',
#  '638884__jcampbe8__golf-swing.mp3',
#  '638884__jcampbe8__golf-swing.mp3.asd',
#  '70+CGC+LUTs.zip',
#  '719_EXD-80',
#  '719_EXD-80.zip',
#  '7226_Odin2',
#  '7226_Odin2.zip',
#  '7z2103-x64.exe',
#  '8-16bit+Sound+assets+(x25)',
#  '90s Jungle sounds Folder',
#  '90s Jungle sounds Folder.zip',
#  '9383_Warmy+EP1A+V2.0.3+(PC)',
#  '9383_Warmy+EP1A+V2.0.3+(PC).zip',
#  '951_Zampler_RX_2.6_PC',
#  '951_Zampler_RX_2.6_PC.zip',
#  '9httdUXx',
#  'A Meal at Texas Joe’s BBQ-1.pdf',
#  'A Meal at Texas Joe’s BBQ.pdf',
#  'A1TriggerGate-v1.4-WinSetup.exe',
#  'A5 2023 Stapled Calendars(1).pdf',
#  'A5 2023 Stapled Calendars.pdf',
#  'AAFEB2A7-92C9-4C48-924A-D48EF3366A89(1).png',
#  'AAFEB2A7-92C9-4C48-924A-D48EF3366A89(2).png',
#  'AAFEB2A7-92C9-4C48-924A-D48EF3366A89.png',
#  'abandoned_bakery_8k.hdr',
#  'Ableton Live Suite v11.0.11 Windows',
#  'Ableton Live Suite v11.0.11 Windows.rar',
#  'ABSTENCIA FINAL MASTER 07.08.23.wav',
#  'Acidic FINAL MASTER 07.08.23.wav',
#  'ACM New Supplier Form .pdf',
#  'AdaFruit.fzbz',
#  'AFC 22 04 tix',
#  'AFC-chealsea ticket confirm.pdf',
#  'AG will_001.jpg',
#  'AGibbons.docx',
#  'AGibbons.pdf',
#  'AhLt1aOB.html',
#  'amd-software-adrenalin-edition-23.2.1-minimalsetup-230213_web.exe',
#  'amd-software-adrenalin-edition-23.2.2-minimalsetup-230221_web.exe',
#  'Andrew Gibbons Will.pdf',
#  'Andy 1959-1987 FINAL for Rex.docx',
#  'Andy Gibbons - She Walks In Beauty.wav',
#  'another_typewriter',
#  'another_typewriter.zip',
#  'archive',
#  'arid_dn.jpg',
#  'arkitech',
#  'arkitech.zip',
#  'ArthursAudioBPs-main',
#  'ArthursAudioBPs-main.zip',
#  'Arts SU Agreement - JGM SIGNED.pdf',
#  'Arturia',
#  'Arturia_Software_Center__2_7_2_2631.exe',
#  'AscensionVR-SurveyPrint.pdf',
#  'ASIO4ALL_2_15_Beta2_English.exe',
#  'Assessment Brief IU000123 Coding One - Advanced Creative Coding.cleaned (1).pdf',
#  'AtomSetup-x64.exe',
#  'audacity-win-3.1.3-64bit.exe',
#  'audiocheck.net_sin_1000Hz_-3dBFS_5s.wav',
#  'audiocheck.net_sin_100Hz_-3dBFS_3s.wav',
#  'audiocheck.net_whitenoisegaussian.wav',
#  'aurora-borealis-90877.mp4',
#  'Autodesk_EAGLE_9.6.2_English_Win_64bit.exe',
#  'Auto_Tune_Central_1.3.8_x64.exe',
#  'b-VNWH5b',
#  'B2BK_AdvancedRendering_2023.1.toe',
#  'B2BK_AdvancedRendering_2023.toe',
#  'B2BK_PTC_from_OBJ',
#  'B2BK_PTC_from_OBJ.zip',
#  'Backup',
#  'BACKUP MASTERS THESIS FINAL.docx',
#  'Beck formulation diagram.docx',
#  'Belle Tutorial.zip',
#  'Big Trousers Cube + NW Mix Invoice.docx.pdf',
#  'bird2.jpg',
#  'bird3.jpg',
#  'blender-3.0.0-windows-x64.msi',
#  'BlenderFastTrackVol1_MineCraft',
#  'BlenderFastTrackVol1_MineCraft.zip',
#  'blue blood veins v3.mp3',
#  'blue blood veins v3.mp3.asd',
#  'Bluedot 23 invoice 1.docx.pdf',
#  'Bluedot 23 invoice 2.docx.pdf',
#  'bo8F5v0Q.png',
#  'boomcubeMATs',
#  'BOWY FINAL MASTER 07.08.23.wav',
#  'BOWY james clean vox sample_vocals_split_by_lalalai.wav',
#  'BOWY james clean vox sample_vocals_split_by_lalalai.wav.asd',
#  'bowy Mix no Master.wav',
#  'BPB_Analog_Kicks',
#  'BPB_Cassette_909',
#  'BPB_Cassette_909.zip',
#  'brick-rubble-under-the-wall',
#  'brick-rubble-under-the-wall.zip',
#  'Bridge.exe',
#  'brighton train ticket.jpg',
#  'BrunswickPanel_Mod.dxf',
#  'BrunswickPanel_Mod.fpd',
#  'BrunswickPanel_Mod2.svg',
#  'BRUTE FINAL MASTER 07.08.23.wav',
#  'Bunting-Bird-Flying-2-GraphicsFairy.jpg',
#  'CAMHS PPR write up.docx',
#  'CamOrbit_lockedToGeo.toe',
#  'Cathedrale V2.wav',
#  'CAVESFX',
#  'CCI AUDIO LECTURE.pdf',
#  'CCV-1.2-win-bin',
#  'CCV-1.2-win-bin.zip',
#  'CCV-1.5.exe',
#  'checkbook',
#  'checkbook.zip',
#  'CHIOR BOUNCE#01FACE choir print for rmx.wav',
#  'CHIOR BOUNCE#01FACE choir print for rmx.wav.asd',
#  'chroma demo soudns',
#  'Chromaesthesia (AV) Interview 1 - James(1).docx',
#  'Chromaesthesia (AV) Interview 1 - James.docx',
#  'CLIP',
#  'Coding 1 Final Project - FINAL-MIMIC',
#  'Coding 1 Final Project - FINAL-MIMIC.zip',
#  'COding 1 final project read me.txt',
#  'Coding One Weekly Assessment Links - James Gibbons-Macgregor .pdf',
#  'Coding3 Week4',
#  'Coding3 Week4.zip',
#  'Coding3Wk5',
#  'Coding3Wk5.zip',
#  'colorsPerParticle.tox',
#  'Commodore_64_Synthesizer_Sessions_DELUXE.zip',
#  'CompEnvWeek13-main',
#  'CompEnvWeek13-main.zip',
#  'composition-with-calla-lily-floriana-barbu.jpg',
#  'constraint_simulation.zip',
#  'ContractC0080428-06_03_2024 11 19.pdf',
#  'Contract_Information_SIMO.pdf',
#  'Contract_Summary_SIMO.pdf',
#  'ControlSurfacemaster.zip',
#  'converted_keras',
#  'converted_keras.zip',
#  'Copy of MASTERS THESIS FINAL ANON EDIT.docx',
#  'Cover Letter RE Susan Mary Gibbons funeral bills.pdf',
#  'creative_cloud_uninstallerwin',
#  'creative_cloud_uninstallerwin.zip',
#  'CRIT STUDIES FINAL V2.docx.pdf',
#  'Critical Studies Homework Assignments.pdf',
#  'CRT_Filter.tox',
#  'CSC_sweep_20-20k.wav',
#  'CSC_test_pink-noise.wav',
#  'CSC_test_white-noise.wav',
#  'Cura_OriginalPrusa_Profiles',
#  'Cura_OriginalPrusa_Profiles.zip',
#  'Curcitstopo Audio for TD.wav',
#  'CV James Gibbons-MacGregor 2024 docx.docx',
#  'CV James Gibbons-MacGregor 2024-1.pdf',
#  'CV James Gibbons-MacGregor 2024.pdf',
#  'daaci-natural-drums-v0.3.5-e8e9d85f-win_x86_64',
#  'daaci-natural-drums-v0.3.5-e8e9d85f-win_x86_64.zip',
#  'daaci-natural-drums-v0.4.5-9397e20c-win_x86_64.exe',
#  'daaci-natural-drums-v0.4.5-9397e20c-x86_64.pkg',
#  'DARK HORSES - XIII.mp4',
#  'DARK HORSES -- WHILE WE WERE SLEEPING Out this Friday on digital and limited edition coloured vinyl on Portland’s @LittleCloudRecords produced by @bobearland Get yours before it’s too late! LINK in BIO A sp.mp4',
#  'DaVinci_Resolve_17.4_Windows',
#  'DaVinci_Resolve_18.5.1_Windows',
#  'Dawn Dusk Draft 00.mp4',
#  'DAZ webscraper_images_marysia.ipynb',
#  'DDFC50BE-3845-4B59-892E-61240FCF66C4.jpg',
#  'DDWAH (Rough).mp3',
#  'DDWAH (Rough).mp3.asd',
#  'Death Grant form',
#  'Death Grant form.zip',
#  'Death Grant Information Form James.pdf',
#  'Death Grant Information Form Oliver.pdf',
#  'Descript Setup 46.2.0-release.20220816.4.exe',
#  'Descript Setup 48.1.0-release.20220919.20.exe',
#  'desktop.ini',
#  'dfsdfgsdfgdrg',
#  'DISCOBAAL MOVs',
#  'DiscordSetup.exe',
#  'Disco_Diffusion_v5_4_[Now_with_Warp].ipynb',
#  'Distributed drum kit .pdf',
#  'DKB TWO (Ref Mix 19Jun).wav',
#  'DN ollie.mp3',
#  'DN ollie.mp3.asd',
#  'document.pdf',
#  'dolphin-master-5.0-16793-x64',
#  'dolphin-master-5.0-16793-x64.7z',
#  'drakensberg_solitary_mountain_puresky_8k.hdr',
#  'drive-download-20220810T205621Z-001',
#  'drive-download-20220810T205621Z-001.zip',
#  'drive-download-20220822T211607Z-001',
#  'drive-download-20220822T211607Z-001.zip',
#  'drive-download-20220823T015413Z-001',
#  'drive-download-20220823T015413Z-001.zip',
#  'drive-download-20230515T001102Z-001',
#  'drive-download-20230515T001102Z-001.zip',
#  'drive-download-20240621T181420Z-001',
#  'drive-download-20240621T181420Z-001.zip',
#  'drive-download-20240719T175109Z-001',
#  'drive-download-20240719T175109Z-001.zip',
#  'DropboxInstaller.exe',
#  'drum_patterns.mid',
#  'DrvTools(115_r49e)(1).exe',
#  'DrvTools(115_r49e).exe',
#  'DrvTools(115_r51e).exe',
#  'DRWHO time sheet.txt',
#  'DSC_0396__880.jpg',
#  'DSC_3213 Andy Elba Front Page .jpg',
#  'Dsync Processed vocal stems-20240623T115516Z-001',
#  'Dsync Processed vocal stems-20240623T115516Z-001.zip',
#  'ds_digital',
#  'dzsetup.exe',
#  'e8cB2Hgp.html',
#  'edtsd',
#  'edtsd.zip',
#  'emc-xlr.pdf',
#  'ENVwk1DrumSamples',
#  'EpicInstaller-13.0.0-unrealEngine(1).msi',
#  'EpicInstaller-13.0.0-unrealEngine.msi',
#  'EqLt4pvn',
#  'eticket.pdf',
#  'expandable-eurorack-case-blocks20220703-281611-69itwm',
#  'expandable-eurorack-case-blocks20220703-281611-69itwm.zip',
#  'ExploringMachineIntelligence_Spring2022-main',
#  'ExploringMachineIntelligence_Spring2022-main(1).zip',
#  'ExploringMachineIntelligence_Spring2022-main(2)',
#  'ExploringMachineIntelligence_Spring2022-main.zip',
#  'eye video.mp4',
#  'fakes000012.jpg',
#  'fakes000017.jpg',
#  'fakes000029.jpg',
#  'fbx20133_converter_win_x64.exe',
#  'fiction 09_08 INVOICE TEMPLATE V2.docx.pdf',
#  'fiction 13_10 INVOICE.docx.pdf',
#  'fiction 28_02_24 INVOICE.docx.pdf',
#  'Fiction 28_05_24 INVOICE.docx.pdf',
#  'fiction invoice 11_06_23.docx.pdf',
#  'fiction invoice Total.pdf',
#  'Fiction Studios Social Media and Content Agreement-1.pdf',
#  'Fiction Studios Social Media and Content Agreement.pdf',
#  'fidelity cover letter-1.pdf',
#  'fidelity cover letter.pdf',
#  'Filestar.23.0.17.0.win-x64.BN5i8.exe',
#  'FitNote-8014461f-1004-48c3-bbca-cf7000249b4a.pdf',
#  'flower bill.pdf',
#  'Focusrite Control - 3.11.0.1983.exe',
#  'Focusrite Control - 3.6.0.1822.exe',
#  'Food.png',
#  'For James',
#  'For James.zip',
#  'FRACTURE',
#  'FRACTURE.zip',
#  'Frank.usdz',
#  'FreaGAN.pkl',
#  'fritzing.0.9.3b.32.pc',
#  'FrontDesign-EU-6.3.4-x64.exe',
#  'Funeral Expenses combined-combined.pdf',
#  'futurelearn-master',
#  'futurelearn-master.zip',
#  'Fw ISA Deadline extension.eml',
#  'gateCHOPComp.tox',
#  'GenerativeDesign-master',
#  'GenerativeDesign-master.zip',
#  'generic-man-symbol.jpeg',
#  'ghdX9ccU.html',
#  'girl-with-amphora-statue',
#  'girl-with-amphora-statue.zip',
#  'Git-2.33.1-64-bit.exe',
#  'git-lfs-windows-v3.2.0.exe',
#  'GitHubDesktopSetup-x64.exe',
#  'Go Fantasma Stems-20220902T175226Z-001',
#  'goat_skull_ply_1',
#  'guided-diffusion',
#  'hairless-midiserial-0.4-windows',
#  'hairless-midiserial-0.4-windows.zip',
#  'HandBrake-1.6.1-x86_64-Win_GUI.exe',
#  'Hans_Brouwer_Self_supervised_Audio_reactive_Music_Video_Synthesis-1.pdf',
#  'Hans_Brouwer_Self_supervised_Audio_reactive_Music_Video_Synthesis-2.pdf',
#  'Hans_Brouwer_Self_supervised_Audio_reactive_Music_Video_Synthesis.pdf',
#  'HCMS Mixing Cheatsheet 2022 v1.pdf',
#  'Headshot.JPG',
#  'hfsexplorer-2021.10.9-setup.exe',
#  'horses-logo-orange-on-black.png',
#  'HPAS2-New-or-Restarting-Hourly-Paid-Academic-Staff--Pre-Employment-Checks.pdf',
#  'hyg_v35.csv',
#  'iD-v4.3.13a.exe',
#  'images.jpg',
#  'images_out',
#  'IMG-0008.jpg',
#  'IMG-0587.jpg',
#  'IMG_0011.MOV',
#  'IMG_0020.jpg',
#  'IMG_0415.MOV',
#  'IMG_0495.jpg',
#  'IMG_20220705_0013.jpg',
#  'IMG_20230514_0002',
#  'IMG_20230514_0002.zip',
#  'IMG_2239 (1) XMas 2021.JPG',
#  'IMG_2371.MOV',
#  'IMG_2462.jpg',
#  'IMG_2712.MOV',
#  'IMG_2726.MOV',
#  'IMG_2935.MOV',
#  'IMG_2939.MOV',
#  'IMG_3794.JPG',
#  'IMG_3795.jpg',
#  'IMG_4226.MOV',
#  'IMG_4326.JPG',
#  'IMG_4381.jpg',
#  'IMG_4382.jpg',
#  'IMG_4383.jpg',
#  'IMG_4396.MOV',
#  'IMG_4407.MOV',
#  'IMG_4652.MOV',
#  'IMG_4662.MOV',
#  'IMG_4871 Mountain Kefalonia .JPG',
#  'IMG_6897Dolomites Ollie.JPG',
#  'IMG_9235 (1) Menaggio(1).JPG',
#  'IMG_9235 (1) Menaggio.JPG',
#  'iml-ue4-master',
#  'iml-unreal-master',
#  'iml-unreal-master.zip',
#  'init_images',
#  'Installer_OWLLivestreamingToolkit_v0.137.2-ue5.0(1).exe',
#  'Installer_OWLLivestreamingToolkit_v0.137.2-ue5.0.exe',
#  'Installer_OWLLivestreamingToolkit_v0.75.21-ue4.27.0.exe',
#  'Install_Newgrounds_Player.msi',
#  'Interstellar Master FInal2.wav',
#  'IntroToUnrealAssets',
#  'IntroToUnrealAssets.zip',
#  'invoice-KSCU809919-0002.pdf',
#  'ISA GIBBONS-MACGREGOR James 21036397.pdf',
#  'ISA_GIBBONS-MACGREGOR_James_21036397-1.pdf',
#  'ISA_GIBBONS-MACGREGOR_James_21036397.pdf',
#  'istockphoto-535916701-1024x1024.jpg',
#  'j4AL7N4e.html',
#  'jack2-win64-v1.9.20.exe',
#  'jack2-win64-v1.9.21.exe',
#  'JAMES (bold venue)',
#  'JAMES (bold venue).zip',
#  'James Edit.jpg',
#  'James Gibbons-Macgregor - Coding 2 - Element 1 -Lab Work .pdf',
#  'James Gibbons-Macgregor - Coding 2 - Element 1 -Lab Work_.zip',
#  'James Gibbons-Macgregor Adv. Project',
#  'James Gibbons-Macgregor Arts Temp CV (1).docx',
#  'James Gibbons-Macgregor Arts Temp CV .docx',
#  'James Gibbons-Macgregor Audio CV 2021 .pdf',
#  'James Gibbons-Macgregor CV (UAL).pdf',
#  'James Gibbons-Macgregor Music CV .docx',
#  'James Gibbons-Macgregor-Coding 1-Final Project.pdf',
#  'James Gibbons-Macgregor-Coding 1-Final Project.zip',
#  'JAMES GM ADRESS PROOF.pdf',
#  'James GM birth certificate.jpeg',
#  'James GM proof of adress bill-1.pdf',
#  'James GM proof of adress bill.pdf',
#  'James Pixel LIVE10 Version Project-20220901T171841Z-001',
#  'James Pixel LIVE10 Version Project-20220901T171841Z-001.zip',
#  'james-bandw-landscape-mb-10-bday-25-3-23-announce-3.png',
#  'JGM +44 12.04.23 Invoice.pdf',
#  'JGM +44 19.04.23 Invoice.pdf',
#  'JGM 2021-22 Consent to Share Information Form v1.pdf',
#  'JGM Fiction 31_07_24 INVOICE.docx.pdf',
#  'Jl3luhY_.html',
#  'joao-desager-mc-rep-wip-effect-011.jpg',
#  'JOY_RYTM FINAL DEMO.wav',
#  'JOY_RYTM Stems-20220819T173606Z-001',
#  'JS-2-2022-11-15-22-59-09-Seamless.png',
#  'JS-2-2022-11-15-23-00-07-Seamless-Normal.png',
#  'JS-dotGrid-2022-11-15-23-02-00.png',
#  'JSplacement-1.3.0-x64-installer.exe',
#  'junichi-ktp-event-presentation(1).pptx',
#  'junichi-ktp-event-presentation.pptx',
#  'keyviz-v1.0.6.exe',
#  'KinectSDK-v2.0_1409-Setup.exe',
#  'kitten1.jpg',
#  'kittens',
#  'kittens.zip',
#  'Klone(1).mp4',
#  'kloppenheim_02_puresky_4k.hdr',
#  'lampe-wohnzimmer-2017',
#  'lampe-wohnzimmer-2017.zip',
#  'Last Will and Testament.pdf',
#  'Lecture fixed audio.wav',
#  'Legend of Zelda, The - The Wind Waker (USA)',
#  'leicestersquaretheatre_order_142017470.pdf',
#  'Light-Textures-Folder-MS-Word',
#  'Light-Textures-Folder-MS-Word.zip',
#  'lilienstein_2k.hdr',
#  'Lily-1.jpg',
#  'Liontrust cover letter.pdf',
#  'Liontrust probate letter-1.pdf',
#  'Liontrust probate letter.pdf',
#  'LiveGrabber-v5.1.2',
#  'Livesync-3.1.0',
#  'Livesync-3.1.0.zip',
#  'london-tube-font',
#  'london-tube-font.zip',
#  'looperman-l-0064965-0016204-donnievyros-junglish-fishsticks-5.wav',
#  'looperman-l-0064965-0016204-donnievyros-junglish-fishsticks-5.wav.asd',
#  'looperman-l-0291301-0272748-breakbeat-junglebreaks-worm-706kbps.wav',
#  'looperman-l-0291301-0272748-breakbeat-junglebreaks-worm-706kbps.wav.asd',
#  'looperman-l-0291301-0272952-breakbeat-oldschool-scorpio-bt.wav',
#  'looperman-l-0291301-0272952-breakbeat-oldschool-scorpio-bt.wav.asd',
#  'looperman-l-0291301-0282950-junglebreaks-sport-1.wav',
#  'looperman-l-0291301-0282950-junglebreaks-sport-1.wav.asd',
#  'looperman-l-0291301-0282952-junglebreaks-soul-pride.wav.asd',
#  'looperman-l-0291301-0282958-junglebreaks-sniper.wav',
#  'looperman-l-0291301-0282958-junglebreaks-sniper.wav.asd',
#  'looperman-l-0880477-0306981-afrobeat-drumloop-banzu.wav',
#  'looperman-l-0880477-0306981-afrobeat-drumloop-banzu.wav.asd',
#  'looperman-l-1069771-0270069-techno-full-drum-beat - Copy.wav',
#  'looperman-l-1069771-0270069-techno-full-drum-beat.wav',
#  'looperman-l-1069771-0270069-techno-full-drum-beat.wav.asd',
#  'looperman-l-1069771-0270895-dnb-beat.wav',
#  'looperman-l-1314288-0291644-yeat-kankan-cloudten-nightclub20xx.wav',
#  'looperman-l-1314288-0291644-yeat-kankan-cloudten-nightclub20xx.wav.asd',
#  'looperman-l-1564425-0116701-rasputin1963-70s-disco-groove-no9.wav',
#  'looperman-l-1564425-0116701-rasputin1963-70s-disco-groove-no9.wav.asd',
#  'looperman-l-1564425-0308115-1979-disco-beat.wav',
#  'looperman-l-1564425-0308115-1979-disco-beat.wav.asd',
#  'looperman-l-1564425-0313296-70s-italo-samba.wav',
#  'looperman-l-1564425-0313296-70s-italo-samba.wav.asd',
#  'looperman-l-1791901-0332124-funky-disco-beat.wav',
#  'looperman-l-1791901-0332124-funky-disco-beat.wav.asd',
#  'looperman-l-1964484-0105822-tmandjievdo0-alex-caspian-samples-122-bpm-kick.wav',
#  'looperman-l-1964484-0105822-tmandjievdo0-alex-caspian-samples-122-bpm-kick.wav.asd',
#  'looperman-l-1964484-0106817-tmandjievdo0-alex-caspian-samples-120-bpm-deep-house-drums-top.wav',
#  'looperman-l-1964484-0180308-robin-schulz-style-drums-01-full.wav',
#  'looperman-l-1964484-0180308-robin-schulz-style-drums-01-full.wav.asd',
#  'looperman-l-1964484-0283849-20220213-deep-house-drum-loop-no-kick.wav',
#  'looperman-l-1964484-0283849-20220213-deep-house-drum-loop-no-kick.wav.asd',
#  'looperman-l-1964484-0293464-20220429-deep-house-drum-loop-no-kick(1).wav',
#  'looperman-l-1964484-0293464-20220429-deep-house-drum-loop-no-kick.wav',
#  'looperman-l-1964484-0298888-20220619-deep-house-drum-loop-no-kick-1.wav',
#  'looperman-l-1964484-0298888-20220619-deep-house-drum-loop-no-kick-1.wav.asd',
#  'looperman-l-2265390-0186454-tropicalish-drum-loop.wav',
#  'looperman-l-2265390-0186454-tropicalish-drum-loop.wav.asd',
#  'looperman-l-2283018-0110008-amusah-rem-boas-chip-tune-beat-120-bpm.wav',
#  'looperman-l-2283018-0110008-amusah-rem-boas-chip-tune-beat-120-bpm.wav.asd',
#  'looperman-l-2392682-0274137-hard-techno.wav',
#  'looperman-l-2392682-0274137-hard-techno.wav.asd',
#  'looperman-l-2392682-0306619-lofi-breakbeat.wav',
#  'looperman-l-2392682-0306619-lofi-breakbeat.wav.asd',
#  'looperman-l-2392682-0340735-silent-hill.wav',
#  'looperman-l-2392682-0340735-silent-hill.wav.asd',
#  'looperman-l-2392682-0344291-sensation.wav',
#  'looperman-l-2392682-0344291-sensation.wav.asd',
#  'looperman-l-2395177-0262975-iglooghost-style-drums.wav',
#  'looperman-l-2395177-0262975-iglooghost-style-drums.wav.asd',
#  'looperman-l-2777678-0247755-house-beat.wav',
#  'looperman-l-2777678-0247755-house-beat.wav.asd',
#  'looperman-l-2852743-0329717-you-cant-control-me-drumloop.wav',
#  'looperman-l-2852743-0329717-you-cant-control-me-drumloop.wav.asd',
#  'looperman-l-2954682-0198657-kaytranada-drums.wav',
#  'looperman-l-2954682-0198657-kaytranada-drums.wav.asd',
#  'looperman-l-2957643-0290612-background-battlestation.wav',
#  'looperman-l-2957643-0290612-background-battlestation.wav.asd',
#  'looperman-l-2996251-0271938-bouncy-club-drums.wav',
#  'looperman-l-2996251-0271938-bouncy-club-drums.wav.asd',
#  'looperman-l-3083843-0201006-afro-beat.wav',
#  'looperman-l-3083843-0201006-afro-beat.wav.asd',
#  'looperman-l-3270721-0261295-125bpm-boobap-drums.wav',
#  'looperman-l-3270721-0261295-125bpm-boobap-drums.wav.asd',
#  'looperman-l-3270842-0168358-deep-house-kit2-drums-with-kick.wav',
#  'looperman-l-3270842-0168358-deep-house-kit2-drums-with-kick.wav.asd',
#  'looperman-l-4108535-0261852-house-drum-loop.wav',
#  'looperman-l-4108535-0261852-house-drum-loop.wav.asd',
#  'looperman-l-4619740-0321660-all-alone-dex-laurent.wav',
#  'looperman-l-5160982-0316354-fast-drum-break(1).wav',
#  'looperman-l-5160982-0316354-fast-drum-break(1).wav.asd',
#  'looperman-l-5160982-0316354-fast-drum-break.wav',
#  'looperman-l-5160982-0316354-fast-drum-break.wav.asd',
#  'looperman-l-6651918-0361328-deep-house-drums.wav',
#  'looperman-l-6651918-0361328-deep-house-drums.wav.asd',
#  'loopMIDISetup_1_0_16_27',
#  'loopMIDISetup_1_0_16_27.zip',
#  'Losing Notes LIve-20220905T151643Z-001',
#  'Losing Notes LIve-20220905T151643Z-001.zip',
#  'Losing Notes Stems-20220902T175220Z-001',
#  'LPA-for-financial-decisions-make-and-register-complete-pack',
#  'LPA-for-financial-decisions-make-and-register-complete-pack.zip',
#  'LTC_01000000_30mins_30fps_48000x16',
#  'm4l-connection-kit-master',
#  'm4l-connection-kit-master(1)',
#  'm4l-connection-kit-master(1).zip',
#  'm4l-connection-kit-master.zip',
#  'MadMapperDemoSetup.exe',
#  'Magical8bitPlug2-win-210508',
#  'Magical8bitPlug2-win-210508.zip',
#  'main.cpp',
#  'maintenance cycle.docx',
#  'MAP Interview 2 - Design process.docx',
#  'mapdreamer.pkl',
#  'MASTERS THESIS backup 1.docx',
#  'MASTERS THESIS backup 30.11.docx',
#  'MASTERS THESIS backup near final.docx',
#  'MatroskaSplitter.exe',
#  'Max 30th Song Audio.wav',
#  'Max 30th Song Audio.wav.asd',
#  'MB GOLD - 6-11-21 - MCDE.jpeg',
#  'Memory Box, 6-11-21 RED flyer.jpeg',
#  'memorybox_logo_black_300dpi.jpg',
#  'memorybox_logo_black_300dpi.png',
#  'memorybox_logo_white_2017.png',
#  'MenuWatcher.toe',
#  'Meshroom-2021.1.0-win64',
#  'MiDaS',
#  'Midi-CV DIY',
#  'Midi-CV DIY.zip',
#  'midi2cv-master',
#  'midicontrol AUDIO.wav',
#  'MIDI_Control_Center_1_13_5_1.exe',
#  'minilogue_Sound_Librarian_Installer0120',
#  'minilogue_Sound_Librarian_Installer0120.zip',
#  'minilogue_Updater_0201_win',
#  'minilogue_Updater_0201_win.zip',
#  'Mirrored Glass Live-20220905T170634Z-001',
#  'Mirrored Glass Live-20220905T170634Z-001.zip',
#  'MM LIVE STEMS-20230521T213406Z-001',
#  'MM LIVE STEMS-20230521T213406Z-001.zip',
#  'MNLG01-UK Producer Set',
#  'MNLG01-UK Producer Set.zip',
#  'MNLG02-Euro Producer Set',
#  'MNLG02-Euro Producer Set.zip',
#  'models',
#  'moog pulsing loop.wav',
#  'moog pulsing loop.wav.asd',
#  'MoonEcho-1.0',
#  'MoonEcho-1.0.zip',
#  'Motown Medley MUSIC.wav.asd',
#  'murSalon.3.toe',
#  'murSalon.toe',
#  'musicradar-drum-break-samples',
#  'musicradar-drum-break-samples.zip',
#  'musicradar-percussion-loops.zip',
#  'musicradar-synth-samples',
#  'music_zapsplat_game_music_action_retro_8_bit_repeating_016.mp3',
#  'myLearnerData.json',
#  'Mägi_informaatika_2021(1).pdf',
#  'Mägi_informaatika_2021.pdf',
#  'N-drumsGroove.midi',
#  'N-Mhv1fR',
#  'ncKinectv2Core.obj',
#  'NDA James Gibbons-MacGregor.pdf',
#  'NDI 5 Tools.exe',
#  'network-snapshot-010162.pkl',
#  'network-snapshot-011676.pkl',
#  'NewLaw Probate and Estate Administration service guide .pdf',
#  'NLP Week 5 - Web data and generative text.pdf',
#  'NLP Week 5 - Web data and generative text.pptx',
#  'NormalMap_TOP_0.tox',
#  'NUMPY_IMAGES_DEMO.ipynb',
#  'Obxd29Windows',
#  'Obxd29Windows.zip',
#  'ofApp.cpp',
#  'ofApp.h',
#  'office-building-stairwell',
#  'ofxKinectV2-master',
#  'ofxNCKinect-master',
#  'of_v20220121_vs2017_nightly',
#  'OLIVER GM ADRESS PROOF.pdf',
#  'Oliver GM birth certificate.jpeg',
#  'oliver GM drivers licence.jpg',
#  'oliver GM passport.jpg',
#  'OneDrive_1_07-12-2023',
#  'OneDrive_1_07-12-2023.zip',
#  'Opening Clips FINAL 2.mov',
#  'Opening dV Archive.dra',
#  'P1010410.JPG',
#  'P1010416.JPG',
#  'P9P1.jpg',
#  'P9_Ja transcript for coding 2 backup.docx.pdf',
#  'panoptorecorder.exe',
#  'Part A 3.docx',
#  'path4136.png',
#  'PCOMP LAB PORTFOLIO',
#  'PCOMP LAB PORTFOLIO.zip',
#  'PcompSyllabus.pdf',
#  'PComp_WeekOne.pdf',
#  'PD fest image.jpg',
#  'PECKHAM DIGITAL 23.07.24 INVOICE.docx.pdf',
#  'Peckham Digital Agreement - JamesGM.docx.pdf',
#  'penguins-skybox-pack',
#  'penguins-skybox-pack.zip',
#  'peony-point-cloud',
#  'PHOTO-2022-07-08-13-15-49 Council Chamber.jpg',
#  'PHOTO-2023-05-15-01-41-20.jpg',
#  'Pixel Art Diffusion(1).mp4',
#  'Pixel Art Diffusion(2).mp4',
#  'PL x MB square.jpg',
#  'placeholder-social.png',
#  'png man.png',
#  'prejestice synth jam master .wav',
#  'probate contract 1.pdf',
#  'Probate contract 2.pdf',
#  'probate contract 3.pdf',
#  'Proposal for final essay, Crit studies wk 5 .pdf',
#  'protokol-0.4.4.86-win64.exe',
#  'Prototyping presentation.pdf',
#  'prusa3d_win_2_5_0.exe',
#  'python-3.11.9-amd64.exe',
#  'pytorch3d-lite',
#  'qr-code.png',
#  'quickPatterns-init',
#  'quickPatterns.zip',
#  'radio-land',
#  'radio-land.zip',
#  'rave_render(1).wav',
#  'rave_render(1).wav.asd',
#  'rave_render(2).wav',
#  'rave_render(2).wav.asd',
#  'rave_render(3).wav',
#  'rave_render(4).wav',
#  'rave_render(5).wav',
#  'rave_render(5).wav.asd',
#  'rave_render(6).wav',
#  'rave_render(6).wav.asd',
#  'rave_render.wav',
#  'rave_render.wav.asd',
#  'Read Me.txt',
#  'Read Me_1.txt',
#  'Reading slides-20211012',
#  'Reading slides-20211012.zip',
#  'Receipt-23Jul2023-090129.pdf',
#  'Receipt-829916-FLY211009-07-Sep-2021.pdf',
#  'Receipt_17May2023_210235.pdf',
#  'recycle_items(1).png',
#  'recycle_items.png',
#  'RemoteAstrophotography-com-M8_and_M20.zip',
#  'RemoteAstrophotography-com-NGC2070-narrowband',
#  'RemoteAstrophotography-com-NGC2070-narrowband.zip',
#  'ResizeRight',
#  'Rice_Image_Dataset',
#  'Rock Paper Scissors.v1-raw-300x300.folder.zip',
#  'rosat_pspc_rdf2_3_basic.fits',
#  'roundabout video.mp4',
#  'rtpMIDISetup_1_1_14_247',
#  'rtpMIDISetup_1_1_14_247.zip',
#  'Rush Edit 2.mp4',
#  'Rush Edit.mp4',
#  's funeral notes.pdf',
#  'sam number vox samples',
#  'sarah P9 grabs',
#  'Screenshot 2023-03-17 at 17-13-35 DARK HORSES (@darkhorsesmusic) • Instagram photos and videos.png',
#  'Selects-20220606T112634Z-001',
#  'Selects-20220606T112634Z-001.zip',
#  'Self-employed for tax form ACM.pdf',
#  'SerialCOM_4_UE503.zip',
#  'SerumTemplate_0.1.toe',
#  'SerumTemplate_0.toe',
#  'Service user feedback parent and child E.pdf',
#  'SetupAvisFV30',
#  'SetupAvisFV30.zip',
#  'Sh17vHYx',
#  'Simonis_Menukaart_Simonis_aan_de_haven.pdf',
#  'Simple-Folder-Folder-Ms-Word-1',
#  'Simple-Folder-Folder-Ms-Word-1.zip',
#  'sitting-woman-sculpture',
#  'sitting-woman-sculpture.zip',
#  'skinnerbox2049_v8.0',
#  'skinnerbox2049_v8.0.zip',
#  'SlackSetup.exe',
#  'slice BG track no VFX.wav',
#  'slice BG track no VFX.wav.asd',
#  'slice BG track Vocals.wav',
#  'slice BG track Vocals.wav.asd',
#  'slice BG VOCALS only.wav',
#  'slice BG VOCALS only.wav.asd',
#  'SMU Stems',
#  'SMU Stems.zip',
#  'soundSynth',
#  'soundSynth.zip',
#  'SPAM text message 20170820 - Data.csv',
#  'SPIRAL(3).mp4',
#  'SPIRALzoomTest(1).mp4',
#  'SPIRALzoomTest(2).mp4',
#  'SPIRALzoomTest.mp4',
#  'Spirit Airlines booking.pdf',
#  'SpitfireAudio-Win-3.3.23.exe',
#  'SPOUT-2007-009',
#  'Spout-UE4-master',
#  'Spout-UE4-master.zip',
#  'Square',
#  'statement_577940_4426243 (1) GAS.pdf',
#  'statement_577940_4426243-1.pdf',
#  'statement_577940_4426243.pdf',
#  'statement_578063_4434232-1.pdf',
#  'statement_578063_4434232.pdf',
#  'statue-of-a-seated-girl',
#  'statue-of-a-seated-girl.zip',
#  'SteamSetup.exe',
#  'stencil-font-mind-the-gap',
#  'stencil-font-mind-the-gap.zip',
#  'StyleGAN2_microscopev1.pkl',
#  'sublime-glsl-master',
#  'sublime-glsl-master.zip',
#  'sublime_text_build_4143_x64_setup.exe',
#  'submit_config.pkl',
#  'Super Mario Galaxy 2 (USA) (En,Fr,Es)',
#  'susan-1.pdf',
#  'susan-2.pdf',
#  'susan-3.pdf',
#  'susan.pdf',
#  'suzie 2.pdf',
#  'symbol-of-man-icon-5923.jpeg',
#  'Taiko Instrument v2.alp',
#  'Taiko One Shots',
#  'Taiko One Shots.zip',
#  'TAL-BassLine-x64',
#  'TAL-BassLine-x64.zip',
#  'TAL-U-No-62-x64',
#  'TAL-U-No-62-x64.zip',
#  'tardis',
#  'tardis image.obj',
#  'tardis image.ply',
#  'tardis-fan-model',
#  'tardis-wip-v8',
#  'TD class 1 Slides.pdf',
#  'TD-chainGpu-Physics-Sim-Tool-main',
#  'TD-chainGpu-Physics-Sim-Tool-main.zip',
#  'td-glitch-effects-master.zip',
#  'td-quadtree-filter-master.zip',
#  'TeamsSetupx64_s_8D9A5DA6C3E9903-7-0_.exe',
#  'Teams_windows_x64.exe',
#  'TeamViewerQS.exe',
#  'Test Hum 1.wav',
#  'Test Hum 1.wav.asd',
#  'Test Hum 2.wav',
#  'Test Hum 2.wav.asd',
#  'Test pattern images',
#  'The Late Miss S Gibbons.pdf',
#  'The Right to Erasure .pdf',
#  'The_Art_of_the_VJ_The_Origin_of_a_Comple-1.pdf',
#  'The_Art_of_the_VJ_The_Origin_of_a_Comple.pdf',
#  'ThingsTexture-1.1.1',
#  'ThingsTexture-1.1.1.zip',
#  'ticket-vouchers.pdf',
#  'topoexport-1D50A7(1).zip',
#  'topoexport-1D50A7.zip',
#  'topoexport-686408.zip',
#  'topoexport-714DA1.zip',
#  'topoexport-7D2953.zip',
#  'topoexport-9CA3BD.zip',
#  'Touch FX.wav',
#  'Touchdesigner Example Workshop proposal.pdf',
#  'Touchdesigner session invoice 11.03.24 James Gibbons-MacGregor.pdf',
#  'Touchdesigner session invoice 11.03.24 JGM.pdf',
#  'TouchDesigner.2022.33600.exe',
#  'TouchDesigner.2023.11340.exe',
#  'TouchDesignerWebInstaller.2023.11760.exe',
#  'TouchDesigner_Shared-master.zip',
#  'tr-food-menu-v1.pdf',
#  'tsps_win_1.3.6',
#  'tsps_win_1.3.6.zip',
#  'ua4fx_w10d_v100',
#  'ua4fx_w10d_v100.zip',
#  'UAD-v10.2.2-Windows(2)',
#  'UAL CH Brief 2023.pdf',
#  'UAL MASTERS CV PDF.pdf',
#  'UCD372_James_Gibbons-Macgregor.pdf',
#  'Ultimaker-Cura-5.1.1-win64.exe',
#  'Undine St(1).m4a',
#  'Undine St.m4a',
#  'UnityHubSetup.exe',
#  'Unreal IML JAM MASTER.wav',
#  'unreal-audio-dsp-template-UE5-main',
#  'unreal-audio-dsp-template-UE5-main(1).zip',
#  'unreal-audio-dsp-template-UE5-main.zip',
#  'Unreal_Engine_SerialCOM_Plugin-main',
#  'Unreal_Engine_SerialCOM_Plugin-main.zip',
#  'Untitled document.pdf',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'uogX-7RH',
#  'UserBenchmarkInstaller.exe',
#  'us_national_gallery_objects.csv',
#  'vaccine-declarationform-20220208.pdf',
#  'Vacuum Pro_1.0.7.21000_Setup_Windows-GM.exe',
#  'Vacuum Pro_1.0.7.21000_Setup_Windows-GM.exe.zip',
#  'ValhallaSupermassiveWin_V3_0_0b3',
#  'ValhallaSupermassiveWin_V3_0_0b3.zip',
#  'vanadine',
#  'vanadine.zip',
#  'VBCABLE_Driver_Pack43',
#  'VBCABLE_Driver_Pack43(1)',
#  'VBCABLE_Driver_Pack43(1).zip',
#  'vhs_Flair_7097e9ded8.tox',
#  'vigliensoni22UAL.pdf',
#  "Vimm's Lair.txt",
#  'VisualStudioSetup(1).exe',
#  'VisualStudioSetup.exe',
#  'vlc-3.0.16-win64.exe',
#  'Vocals#07.aiff',
#  'Vocals#07.aiff.asd',
#  'Vocals#29.aiff',
#  'Vocals#29.aiff.asd',
#  'VoicemeeterSetup.exe',
#  'VoltaCreate-Windows.exe',
#  'VoltaMaxForLive-21-11-16-B',
#  'VoltaMaxForLive-21-11-16-B.zip',
#  'VOX 2 NO TUNE BEAMS.wav',
#  'VOX 2 NO TUNE BEAMS.wav.asd',
#  'VSCodeUserSetup-x64-1.61.2.exe',
#  'vs_community__92d8550cc5ae4e1698caeb6f0ab6f4d0.exe',
#  'w0bv0102t_c0h.fit.gz',
#  'WaterFall.9.toe',
#  'WaterFall.toe',
#  'Wealth-Initial CR 5_encrypted_.pdf',
#  'Week5dcgan.ipynb',
#  'week_3_practice_web_crawling.ipynb',
#  'wetransfer_dry-stems-bounce-strathcycle_2024-08-06_0808.zip',
#  'wetransfer_i-am-alive-mediatracks-brief-1-dry-stems_2024-07-30_2115',
#  'wetransfer_i-am-alive-mediatracks-brief-1-dry-stems_2024-07-30_2115.zip',
#  'wetransfer_tuck-demo-and-vocal-stems_2024-04-21_1738',
#  'wetransfer_tuck-demo-and-vocal-stems_2024-04-21_1738.zip',
#  'Win Cymatics Origin 1.0.0',
#  'Win Cymatics Origin 1.0.0.zip',
#  'win-mg2500-1_1-mcd(1).exe',
#  'win-mg2500-1_1-mcd.exe',
#  'win-mg7100-1_1-mcd.exe',
#  'win-ts3100-1_1-n_mcd.exe',
#  'WIND Vocals.wav',
#  'WIND Vocals.wav.asd',
#  'windirstat1_1_2_setup.exe',
#  'windowsdesktop-runtime-3.1.27-win-x64.exe',
#  'wireless sarah vids - Shortcut.lnk',
#  'WIRELESS Voices.wav',
#  'Wollo Beat 1.mid',
#  'Wollo Beat 1_1.mid',
#  'WOLLO BEAT 2.dll',
#  'Wollo Beat 2.mid',
#  'Wollo Beat 2_1.mid',
#  'Wollo Beat 3.mid',
#  'Wollo Beat 3_1.mid',
#  'XboxInstaller(1).exe',
#  'XboxInstaller.exe',
#  'xp68-win-mg2500-5_70-ea32_2.exe',
#  'XR9SItv1.html',
#  'Y2Mate.is - ARTARCHITECTURE - Cy Twombly-E56P55i3HHQ-128k-1649720195916.mp3',
#  'Y2Mate.is - ARTARCHITECTURE - Cy Twombly-E56P55i3HHQ-128k-1649720195916.mp3.asd',
#  'y2mate.is - Baron Von Trax Soleil-LE-ExT9mGlI-192k-1692652052.mp3',
#  'y2mate.is - Baron Von Trax Soleil-LE-ExT9mGlI-192k-1692652052.mp3.asd',
#  'Y2Mate.is - Bonobo & Jacques Greene - Fold (Official Audio)-hI7gk8soh7Y-64k-1654650989962.mp3',
#  'Y2Mate.is - Choca Las Caderas (7 Samurai Ciucciotto Re-Edit)-GsGb888X9WE-160k-1654442292985.mp3',
#  'Y2Mate.is - Choca Las Caderas (7 Samurai Ciucciotto Re-Edit)-GsGb888X9WE-160k-1654442292985.mp3.asd',
#  'Y2Mate.is - Daisuke - El Huervo-EL_pBJN_O3M-128k-1660143659680(1).mp3',
#  'Y2Mate.is - Daisuke - El Huervo-EL_pBJN_O3M-128k-1660143659680.mp3',
#  'Y2Mate.is - Dark Horses - Alone (Official Music Video)-erY-cZESeQc-128k-1654859531519.mp3',
#  'y2mate.is - Fifth Doctor Title Sequence Doctor Who-FxODkExkNB4-720p-1687356738.mp4',
#  'y2mate.is - Fourth Doctor 1980 Title Sequence Doctor Who-DKFueZz5Cy4-720p-1687356709.mp4',
#  'y2mate.is - Free Like The Sound-k1lRzLqs6g8-192k-1692652026.mp3',
#  'y2mate.is - Free Like The Sound-k1lRzLqs6g8-192k-1692652026.mp3.asd',
#  'y2mate.is - old_tube_trains_on_the_northern_line-sKLnDVzOQrk-480pp-1688665644.mp4',
#  'Y2Mate.is - Paranoid London, Mutado Pintado - Transmission 5 (Official) Paranoid London RecordsPDONLP001D-54RvgwQfwso-160k-1659575132175.mp3',
#  'Y2Mate.is - Paranoid London, Mutado Pintado - Transmission 5 (Official) Paranoid London RecordsPDONLP001D-54RvgwQfwso-160k-1659575132175.mp3.asd',
#  'Y2Mate.is - Sandstorms (C2 2011 Version)-xry0pApprps-160k-1649709728130.mp3',
#  'y2mate.is - Spin It-GPtvuxaiV00-192k-1692652115.mp3',
#  'y2mate.is - Spin It-GPtvuxaiV00-192k-1692652115.mp3.asd',
#  'Y2Mate.is - The chimes of Big Ben-wqslA_CKub8-48k-1642821294926.mp3',
#  'Y2Mate.is - The chimes of Big Ben-wqslA_CKub8-48k-1642821294926.mp3.asd',
#  'y2mate.is - Water Jump-yv1WsOaab_k-192k-1704972668.mp3',
#  'y3nlkiqj.html',
#  'yorkshire build cover letter.pdf',
#  'YU SAN VIDEO CONENT',
#  'z1IOv35N.html',
#  '[YT2mp3.info] - Danilo Plessow - Nightfall (320kbps).mp3.asd']

# %%
# if the folder where we want to save the images is not already there, create it
if IMAGES_DIRECTORY not in current_dirs:
    os.mkdir(IMAGES_DIRECTORY)  # this directory will be created in the same location where your notebook is

# %%
errors = []

requests.adapters.DEFAULT_RETRIES = 10

# the "enumerate" function allows for iteration while also supplying an index for each item
for img_index, img_url in enumerate(unique_urls):
    
    # get the data from the image url
    resp = requests.get(img_url, stream=True)

    # if the request is not completed
    if resp.status_code != 200:
        # add the image url to the errors list
        errors.append(img_url)
        
    # otherwise, proceed
    else:
        # create a PIL.Image object
        obj_img = Image.open(resp.raw)
        # get the file extension from the url
        img_type = img_url.split('.')[-1]
        # save the image in its origial extension
        obj_img.save(f'./{IMAGES_DIRECTORY}/img_{img_index}.{img_type}')

# %%
# how many errors?
len(errors)
# Out:
# 10

# %%
# let's see what's happened here!
errors[0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Narwhal_Goblet_%2830061080057%29.jpg/220px-Narwhal_Goblet_%2830061080057%29.jpg'

# %%
resp = requests.get(errors[0], stream=True)

# %%
resp.status_code # 403 is the status code for "Permission denied"
# Out:
# 403
