# %%
# Session 10: API's
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.1' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
